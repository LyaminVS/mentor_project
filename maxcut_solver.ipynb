# %%
import QAOAQuquarts
import networkx as nx
import numpy as np
import scipy
import cirq

# %%
G = nx.Graph()
n = 5
G.add_nodes_from([i for i in range(0, n)])
G.add_edges_from([(i, (i + 1) % n) for i in range(0, n)])

solver = QAOAQuquarts.MAXCUTSolver(qudit_dimension=4, layers=4, graph=G, weights=[1, 1, 1, 1, 1])
solver.draw_graph()

# %%
solver.draw_circuit()

# %%
solver.solve()

# %%
solver.get_hist(0.4)

# %%
solver.draw_colored_graph()

# %%
solver.get_best_params()
# Out:
# array([0.20687025, 0.36721459])

# %%
solver.classical_solve()
# Out:
# ['00101',
#  '01001',
#  '01010',
#  '01011',
#  '01101',
#  '10010',
#  '10100',
#  '10101',
#  '10110',
#  '11010']
