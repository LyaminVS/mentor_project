# %%
import QAOAQuquarts
import networkx as nx
import numpy as np
import scipy
import cirq

# %%
G = nx.Graph()
n = 4
G.add_nodes_from([i for i in range(0, n)])
G.add_edges_from([(i, (i + 1) % n) for i in range(0, n)])
solver = QAOAQuquarts.MAXCUTSolver(4, layers=4, graph=G)
solver.draw_graph()

# %%
solver.draw_circuit()

# %%
solver.solve()

# %%
solver.get_hist(0.4)

# %%
solver.get_colored_graph()

# %%
solver.get_best_params()
# Out:
# array([2.90900295, 0.72428037])

# %%
solver.classical_solve()
# Out:
# ['0101', '1010']
