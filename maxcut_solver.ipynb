# %%
import QAOAQuquarts
import networkx as nx
import numpy as np
import scipy
import cirq

# %%
G = nx.Graph()
n = 5
G.add_nodes_from([i for i in range(0, n)])
G.add_edges_from([(i, (i + 1) % n) for i in range(0, n)])

solver = QAOAQuquarts.MAXCUTSolver(qudit_dimension=4, layers=1, number_of_restarts=1, graph=G, weights = [1, 1, 1, 1, 1], noise=True)
solver.draw_graph()

# %%
solver.draw_circuit()

# %%
solver.solve()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
solver.get_hist(0.4)

# %%
solver.draw_colored_graph()

# %%
solver.get_fidelities()
# Out:
# [1.0,
#  1.0233765619901192,
#  0.9971868538627895,
#  0.9992580598424219,
#  0.9927479856679646,
#  0.9923579627801224,
#  0.8991339692202338,
#  0.8982021040853319,
#  0.8123141008493349,
#  0.8124443251759317,
#  0.8054431954087846,
#  0.8059191400921151,
#  0.7276204652913663,
#  0.7273772519290702,
#  0.7085221340196632,
#  0.0]

# %%
solver.get_best_params()
# Out:
# [array([1.75326065, 1.22539915])]

# %%
solver.classical_solve()
# Out:
# ['00101',
#  '01001',
#  '01010',
#  '01011',
#  '01101',
#  '10010',
#  '10100',
#  '10101',
#  '10110',
#  '11010']

# %%
solver = QAOAQuquarts.MAXCUTSolver(qudit_dimension=2, layers=1, number_of_restarts=1, graph=G, weights = [1, 1, 1, 1, 1], noise=True)
solver.draw_graph()

# %%
solver.draw_circuit()

# %%
solver.solve()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
solver.get_hist(0.4)

# %%
solver.draw_colored_graph()

# %%
solver.get_fidelities()
# Out:
# [1.0,
#  1.0019662499331758,
#  1.0019662499331758,
#  1.0062962623269556,
#  0.9261570078905521,
#  0.9259466169314692,
#  0.7747946913914348,
#  0.7746963742527591,
#  0.7084945399805207,
#  0.7082685901032306,
#  0.6449163651008263,
#  0.6438204963894947,
#  0.6214936330181899,
#  0.0]
