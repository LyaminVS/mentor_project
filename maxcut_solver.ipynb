# %%
import QAOAQuquarts
import networkx as nx
import numpy as np
import scipy
import cirq

# %%
G = nx.Graph()
n = 5
G.add_nodes_from([i for i in range(0, n)])
G.add_edges_from([(i, (i + 1) % n) for i in range(0, n)])

solver = QAOAQuquarts.MAXCUTSolver(qudit_dimension=4, layers=1, number_of_restarts=1, graph=G, weights = [10, 10, 1, 1, 1], noise=True)
solver.draw_graph()

# %%
solver.draw_circuit()

# %%
solver.solve()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
solver.get_hist(0.4)

# %%
solver.draw_colored_graph()

# %%
solver.get_best_params()
# Out:
# [array([-0.30307607, -0.98486744])]

# %%
solver.classical_solve()
# Out:
# ['01001', '01011', '01101', '10010', '10100', '10110']

# %%
solver = QAOAQuquarts.MAXCUTSolver(qudit_dimension=2, layers=1, number_of_restarts=1, graph=G, weights = [10, 10, 1, 1, 1], noise=True)
solver.draw_graph()
print(solver.is_odd)
# Out:
# False

# %%
solver.draw_circuit()

# %%
solver.solve()
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
solver.get_hist(0.4)

# %%
solver.draw_colored_graph()
